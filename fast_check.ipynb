# %%
from fast_utils import *

# %%
launch_analysis(
    "/rds/rds-clecat/generative_modelling/results/patch_lon0_lat0/synth_filtered",#/patch_st_filtered_000.npy",
    target="/rds/rds-clecat/generative_modelling/patches/patch_lon0.0_lat0.0_npix256_reso2.34arcmin.npy",
    imshow=0,
    imshow_target=0,
    gaussian=True,
    gaussian_n=10,
    pdf_bins=80,
    pdf_range=(-10, 43),
)
# Out:
# /rds/rds-clecat/generative_modelling/fast_utils.py:351: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(top=0.78)
# {'synth_count': 3, 'target_count': 1, 'gaussian_count': 10}
